# %% [markdown]
# Cropped folder

# %%
import cv2
import os
from google.colab import drive


# drive.mount('/content/drive')

# input_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Cropped/Anomaly"
# output_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Cropped/Canny Edge/Anomaly"


input_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Cropped/Normal"
output_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Cropped/Canny Edge/Normal"



def apply_canny_edge_detection(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    edges = cv2.Canny(image, 100, 200)
    return edges

for filename in os.listdir(input_folder):
  input_image_path = os.path.join(input_folder, filename)
  output_image_path = os.path.join(output_folder, filename)

  edges = apply_canny_edge_detection(input_image_path)
  cv2.imwrite(output_image_path, edges)

print("Edge detection completed and images saved to the output folder.")
# Out:
# Edge detection completed and images saved to the output folder.

# %% [markdown]
# Augmented images

# %%
import cv2
import os
from google.colab import drive


# drive.mount('/content/drive')

# input_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Augmented/Anomaly"
# output_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Augmented/Canny Edge/Anomaly"


input_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Augmented/Normal"
output_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Augmented/Canny Edge/Normal"



def apply_canny_edge_detection(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    edges = cv2.Canny(image, 100, 200)
    return edges

for filename in os.listdir(input_folder):
  input_image_path = os.path.join(input_folder, filename)
  output_image_path = os.path.join(output_folder, filename)

  edges = apply_canny_edge_detection(input_image_path)
  cv2.imwrite(output_image_path, edges)

print("Edge detection completed and images saved to the output folder.")
# Out:
# Edge detection completed and images saved to the output folder.

# %% [markdown]
# Sub Images

# %%
import cv2
import os
from google.colab import drive


# drive.mount('/content/drive')

# input_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Sub Images/Train/Anomaly"
# output_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Sub Images/Canny Edge/Train/Anomaly"

# input_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Sub Images/Test/Anomaly"
# output_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Sub Images/Canny Edge/Test/Anomaly"

# input_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Sub Images/Train/Normal"
# output_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Sub Images/Canny Edge/Train/Normal"

input_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Sub Images/Test/Normal"
output_folder = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Sub Images/Canny Edge/Test/Normal"



def apply_canny_edge_detection(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    edges = cv2.Canny(image, 100, 200)
    return edges

for filename in os.listdir(input_folder):
  input_image_path = os.path.join(input_folder, filename)
  output_image_path = os.path.join(output_folder, filename)

  edges = apply_canny_edge_detection(input_image_path)
  cv2.imwrite(output_image_path, edges)

print("Edge detection completed and images saved to the output folder.")
# Out:
# Edge detection completed and images saved to the output folder.
