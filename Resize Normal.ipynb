# %%
import cv2
import os
import shutil
import numpy as np
from PIL import Image
from google.colab import drive


# drive.mount('/content/drive')

src = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Unprocessed/Normal"
dst = "/content/drive/MyDrive/Colab Notebooks/faulty-product-detection/Data/Aug/Nor"

# if not os.path.exists(dst):
#     os.makedirs(dst)
w,h = 1500, 1000
left = 350
top = 50
right = 1150
bottom = 950


for image_file in os.listdir(src):
  image_path = os.path.join(src, image_file)
  image = Image.open(image_path)
  cropped_image = image.crop((left, top, right, bottom))
  dst_path = os.path.join(dst, image_file)
  cropped_image.save(dst_path)
